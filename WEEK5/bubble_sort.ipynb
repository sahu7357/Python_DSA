# %%
"""
Bubble sort is a sorting algorithm that compares two adjacent elements and swaps them until they are in the intended order.
Time complexity of O(n^2)

"""

# %%
def bubblesort(arr):
    n = len(arr)

    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

list1 = [2, 1, 10, 5, 8]
print("Before: ", list1)
bubblesort(list1)
print("After: ", list1)
for l in list1:
    print(l)
# Out:
# Before:  [2, 1, 10, 5, 8]
# After:  [1, 2, 5, 8, 10]
# 1
# 2
# 5
# 8
# 10

# %%
def bubble(arr):
    n = len(arr)
    for i in range(n):
        print("\n")
        for j in range( 0, n -i -1):
            
            print(j)
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

arr1 = [10, 4, 9, 100, 22, 64]
print("Before:", arr1)
bubble(arr1)
print("After:", arr1)
# Out:
# Before: [10, 4, 9, 100, 22, 64]
#
#
# 0
# 1
# 2
# 3
# 4
#
#
# 0
# 1
# 2
# 3
#
#
# 0
# 1
# 2
#
#
# 0
# 1
#
#
# 0
#
#
# After: [4, 9, 10, 22, 64, 100]

# %%
swapped = False
if not swapped:
    print("hey")
# Out:
# hey

# %%
#Optimised bubble sort

def opbs(arr):
    n = len(arr)

    for i in range(n):
        print("\n")
        swapped = False

        for j in range(0, n -i -1):
            print(j)
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

                swapped = True

        if not swapped:
            break

arr2 = [10, 4, 9, 100, 22, 64]
print("Before:", arr2)
opbs(arr2)
print("After:", arr2)
# Out:
# Before: [10, 4, 9, 100, 22, 64]
#
#
# 0
# 1
# 2
# 3
# 4
#
#
# 0
# 1
# 2
# 3
# After: [4, 9, 10, 22, 64, 100]

# %%
#In outer loop iteration if no swap occurs then the loop terminates early
